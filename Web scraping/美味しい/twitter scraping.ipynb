# %%
# -*- coding: utf-8 -*-
import sys
import os
import bs4
import json
import urllib
import requests
import re

#from da_vinci import Image
from time import sleep

#import pdb; pdb.set_trace()

# クロールしたいユーザのID
crawle_word = '美味しい'


def outputCsv(screen_name, user_name, tweet_timestamp, tweet_body):
    """
    # データをCSVに書き出す
    #  @params screen_name       string              ユーザのスクリーン上の名前（例：Nな人）
    #  @params user_name         string              ユーザの半角英数の名前（例：nnahito）
    #  @params tweet_timestamp   string              ツイート日時
    #  @params tweet_body        string              ツイート本文
    """

    # 書き出すファイル名を決定（ユーザ名.csv）
    file_name = 'outoput.csv'

    # 改行などを削除
    screen_name = screen_name.replace('\n','').replace('\r','')
    user_name = user_name.replace('\n','').replace('\r','')
    tweet_body = tweet_body.replace('\n','').replace('\r','')

    # 出力
    f = open(file_name, 'a')
    f.write(screen_name + ',' + user_name + ',' + tweet_timestamp + ',' + tweet_body + ',' + "\n")
    f.close()


def parseHtml(html_data):
    """
    # 与えられたHTMLをパースしてファイルに書き出します
    #  @paramas html_data           解析したいHTML
    """
    # HTMLを解析
    soup = bs4.BeautifulSoup(html_data)

    # ツイートをブロック単位（ul）に分解
    tweet_blocks = soup.select('.tweet')

    # ツイートのブロックを一つずつ抽出
    for tweet_block in tweet_blocks:
        # スクリーンネームを取得
        screen_name = tweet_block.select('.fullname')[0].text

        # ユーザネームを取得
        user_name = tweet_block.select('.username')[0].text

        # ツイートの日時を取得
        tweet_timestamp = tweet_block.select('.tweet-timestamp')[0].text

        # ツイート内容を取得
        tweet_body = tweet_block.select('.tweet-text')[0].text

        # CSVに出力
        print(screen_name + ',' + user_name + ',' + tweet_timestamp + ',' + tweet_body + ',' + "\n")
        outputCsv(screen_name, user_name, tweet_timestamp, tweet_body)


def getMinPosition(response_json):
    

    # 値を返却
    return response_json["min_position"]


def getNextTweet(crawle_word, max_position):
    """
    # 与えられたポジションから再帰的にクロールを始めます
    #  @params user_id      string          Twitter上の半角英数のユーザ名（例：nnahito）
    #  @params max_position string          次のTwitterのつぶやきID
    """
    headers = {"User-Agent": "Firefox"}
    res=requests.get("https://twitter.com/i/search/timeline",
        params={"q": urllib.parse.quote(crawle_word),
        "vertical": "default",
        "max_position": "hoge",
        "src": "typd",
        "include_entities": "1",
        "include_available_features": "1",
        "lang": "en"
        }, headers=headers)
    
    content=res.json()
    # 次取得のIDを記録しておく
    next_position = content['min_position']

    # HTMLをパースしてファイルに書き出し
    parseHtml(content['items_html'])
    print(next_position + 'の出力完了')

    # 一応スリープをかませる
    sleep(1)

    # 再起的に呼び出す
    getNextTweet(crawle_word, next_position)


def getFirstTweet(crawle_word):
    """
    # 与えられたUserIDから、最初のTweetを取得します
    #  @params user_id      string          取得したいユーザの半角英数のユーザ名（例：nnahito）
    """
    # ベースURLからデータを取得

    headers = {"User-Agent": "Firefox"}
    res=requests.get("https://twitter.com/i/search/timeline",
        params={"q": urllib.parse.quote(crawle_word),
        "vertical": "default",
        "max_position": "hoge",
        "src": "typd",
        "include_entities": "1",
        "include_available_features": "1",
        "lang": "en"
        }, headers=headers)
    htmldata=res.json()["items_html"]
    #print(res.json())

    # パースして書き出し
    parseHtml(html_data)

    # 取得開始位置を取得
    max_position = getMinPosition(res.json())
    #print(max_position)
    # 次
    getNextTweet(crawle_word, max_position)

# プログラム実行
getFirstTweet(crawle_word)
# Out:
# /home/shuichi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home
# ごちそうさまでした pic.twitter.com/ViJwNBANkr,
#
# TWEET--972298261343092741-...-T-0-0の出力完了
# nalunalu51,@midnitehour0404,55s55 seconds ago,got Bali Buda's Raw Honeylove this honey
# #bali
# #canggu
# #balibuda
# #美味しい
# #野菜の煮物にこのハチミツとココナッツシュガーを使う
# #1本はベストフレンドファミリーのお土産pic.twitter.com/xqZ1dsZysm,
#
# 大井川で逢いましょう,@oigawa_online,1m1 minute ago,大井川で逢いましょう
#
# SLフェスタin千頭
# 楽しいよー　美味しいものがたくさんあるから、
# 遊びに来てね～。,
#
# カフェログ,@cafeloggg,3m3 minutes ago,【カフェマメヒコ@渋谷】
# wifi・全席電源ありのノマドカフェ平日はあんまり混んでないし、静かで長居できる就活生の神様
# もちろんコーヒーが美味しいしご飯のメニューもちゃんとあります
# 今回は豆豆サラダとマメパンを食べましたどっちも美味しくてリピ決定
# #カフェログpic.twitter.com/FgYYC68NW5,
#
# 花,@hana0329,24m24 minutes ago,はぁ…はぁ……まだ子供なのでお肉が柔らかいですね…肉汁が滴るほどジューシーで…将来神絵師になりそうな……可能性の味がする……美味しい！！,
#
# 怒花亭　進虫＠小説家になろう&カクヨム,@meizin39,24m24 minutes ago,恐竜ハンターは美味しい仕事 - カクヨム https://kakuyomu.jp/works/1177354054885088631 …
# 表紙用にヒロインのセラミックこと瀬良美久さんを凄腕絵師キウイ将軍に描いてもらいました。pic.twitter.com/Z0PpTqj4k4,
#
# きみへー,@kimihei,49m49 minutes ago,ちょっと待って！焼き牡蠣に日本酒の振る舞いがあるんだけど！！歩道橋渡ったあと。小長井の牡蠣と日本酒・杵の川。超美味しいです！ご馳走さまです！！(*´ω｀*) pic.twitter.com/2A9GReFMEs,
#
# 神崎　司＠ニートライフ,@tsukasavivim01,50m50 minutes ago,好きなことをして、好きな場所に行き、美味しいものを食べて
# 日々充実しています♪
#
# 親孝行、彼女孝行もでき
# 毎日幸せになりました！
# LIEN＠でノウハウ配信中！
# http://changerion.info/w/29T2e8XC pic.twitter.com/wRXAeTdp4J,
#
# シャーレくんと名付け親,@ideschale,1h1 hour ago,諫早の駅からちょっと歩いてるだけで
# -がんばれレッズ  のプラカードを持った子供たちの一群
# -冷たいお茶どうぞー
# -美味しいプチトマトどうぞー
# と 息つく間もない
# これ、「歩かせる工夫」だよなー,
#
# オイカワマル,@oikawamaru,1h1 hour ago,水道水の水源となっているダムも、美味しい農作物を生産している干拓地も、私がいま乗っている新幹線も、多くの野生生物の生息地と命を奪ってできたものであることは、常々心の片隅に置いておくべきことなのです。,
#
# ニュージーランド政府観光局,@PureNZinJapan,2h2 hours ago,【プレゼントキャンペーン】旅サラダを見てNZに行きたくなりましたね！番組で紹介されたクイーンズタウンで、以下のどちらを体験してみたいですか？こちらのツイートをRTし質問に答えた方の中から抽選で@cookietimejp 様の美味しいクッキーをプレゼントいたします！ #旅サラダNZ　 #クッキータイム,
#
# 藤城リエ / りえ,@FujishiroRie,2h2 hours ago,みんな〜！！寒い中ありがとう〜！！暖かくしてね〜！あとフジヤマサイダーが美味しいよ〜！ pic.twitter.com/tbS2LnaIEA,
# 大井川で逢いましょう,@oigawa_online,1m1 minute ago,大井川で逢いましょう
#
# SLフェスタin千頭
# 楽しいよー　美味しいものがたくさんあるから、
# 遊びに来てね～。,
#
# カフェログ,@cafeloggg,3m3 minutes ago,【カフェマメヒコ@渋谷】
# wifi・全席電源ありのノマドカフェ平日はあんまり混んでないし、静かで長居できる就活生の神様
# もちろんコーヒーが美味しいしご飯のメニューもちゃんとあります
# 今回は豆豆サラダとマメパンを食べましたどっちも美味しくてリピ決定
# #カフェログpic.twitter.com/FgYYC68NW5,
#
# 花,@hana0329,24m24 minutes ago,はぁ…はぁ……まだ子供なのでお肉が柔らかいですね…肉汁が滴るほどジューシーで…将来神絵師になりそうな……可能性の味がする……美味しい！！,
#
# 怒花亭　進虫＠小説家になろう&カクヨム,@meizin39,24m24 minutes ago,恐竜ハンターは美味しい仕事 - カクヨム https://kakuyomu.jp/works/1177354054885088631 …
# 表紙用にヒロインのセラミックこと瀬良美久さんを凄腕絵師キウイ将軍に描いてもらいました。pic.twitter.com/Z0PpTqj4k4,
#
# きみへー,@kimihei,49m49 minutes ago,ちょっと待って！焼き牡蠣に日本酒の振る舞いがあるんだけど！！歩道橋渡ったあと。小長井の牡蠣と日本酒・杵の川。超美味しいです！ご馳走さまです！！(*´ω｀*) pic.twitter.com/2A9GReFMEs,
#
# 神崎　司＠ニートライフ,@tsukasavivim01,50m50 minutes ago,好きなことをして、好きな場所に行き、美味しいものを食べて
# 日々充実しています♪
#
# 親孝行、彼女孝行もでき
# 毎日幸せになりました！
# LIEN＠でノウハウ配信中！
# http://changerion.info/w/29T2e8XC pic.twitter.com/wRXAeTdp4J,
#
# シャーレくんと名付け親,@ideschale,1h1 hour ago,諫早の駅からちょっと歩いてるだけで
# -がんばれレッズ  のプラカードを持った子供たちの一群
# -冷たいお茶どうぞー
# -美味しいプチトマトどうぞー
# と 息つく間もない
# これ、「歩かせる工夫」だよなー,
#
# オイカワマル,@oikawamaru,1h1 hour ago,水道水の水源となっているダムも、美味しい農作物を生産している干拓地も、私がいま乗っている新幹線も、多くの野生生物の生息地と命を奪ってできたものであることは、常々心の片隅に置いておくべきことなのです。,
#
# ニュージーランド政府観光局,@PureNZinJapan,2h2 hours ago,【プレゼントキャンペーン】旅サラダを見てNZに行きたくなりましたね！番組で紹介されたクイーンズタウンで、以下のどちらを体験してみたいですか？こちらのツイートをRTし質問に答えた方の中から抽選で@cookietimejp 様の美味しいクッキーをプレゼントいたします！ #旅サラダNZ　 #クッキータイム,
#
# 藤城リエ / りえ,@FujishiroRie,2h2 hours ago,みんな〜！！寒い中ありがとう〜！！暖かくしてね〜！あとフジヤマサイダーが美味しいよ〜！ pic.twitter.com/tbS2LnaIEA,
#
# JUN MASUDA,@intensive911,2h2 hours ago,#親子丼
# #美味しい #写真 #ブログ #japanesefood #instagood #instagram #instalike #instaphoto #instapic #instadaily #photography #photooftheday #photo #followmePlease check instagram"intensive911"pic.twitter.com/kZkpvyEJ3V,
#
# Fuwatto まるやまキッチン,@fuwattomaruyama,2h2 hours ago,3/10(土)札幌、久しぶりの晴れ
#
# もうここから春でしょ！！
#
# 今日は土曜日お出かけの日、天気もいいし～(*^▽^)/★*☆♪
#
# 本日も選んで楽しい見て嬉しい食べて美味しい～オムライスでお待ちしております。(*^ー^)ノ♪ pic.twitter.com/S5MegIPfGp,
#
# 「ここ一番美味しいとこ」 ✨,@twistedthursday,2h2 hours ago,ensemble cast of pure looking, nhk-approved actors ,
#
# 「ここ一番美味しいとこ」 ✨,@twistedthursday,2h2 hours ago,she appeared in the last two episodes, small role, but totally there xD gila deh, dan itu semua sebelum mereka je heroine. and two of the dudes too! sakaken in totonee and kengo kora in ohisama.,
#
# ÂK4Real @ Katsu-Edit Boat  ⛵️ | カレー美味しい,@OfficialAK4Real,3h3 hours ago,Hi I'm AK and I'm here to ruin the day.,
#
# 立ち上がれマスクマン,@7masukumann7,3h3 hours ago,おはようございます
# 福岡県マスクマン地域は朝から晴天
# 気持ちのよい土曜日ですね~
# 今日も笑顔で~
#
# やわもちシリーズ4つ目
# 「わらびもち」
# これも美味しいです！
# きなことわらびもちが絶妙〜
# 和アイス〜ハマりますね〜
#
# 今日も1日素敵な土曜日をお過ごしください
# よろしくです~ pic.twitter.com/BZeHr6uG6I,
#
# 不識庵謙信（影武者）,@fushikiankage,3h3 hours ago,３月９日『二郎 神田神保町』にて小ラーメンそのまま（初見だし神保町店は麺量が凄いと聞いていた＋ロットを崩さない為に）
# これが神田神保町店かー噂には聞いていたけど美味しい
# 肉も柔らかく最高でした
# そしてロット１抜けでした。
#
# ご馳走様でした pic.twitter.com/waJ3hP9k7H,
#
# しょ一けん,@sho_ken91,3h3 hours ago,松屋製麺所@つくば市
# らーめん＋山水で育ったご飯
#
# 今日の朝飯
# 鹿島へ行く前に久しぶりの訪問
# モチモチツルツルの麺に節の香りがいいスープ、美味い
# ご飯も美味しい
# ご馳走様でした pic.twitter.com/HXVp8awEo6,
#
# かくみや,@kakumiya66611,3h3 hours ago,昨夜の金町製麺
# 沢山美味しいお料理を頂きましたが
# 無精者のワタシはコレだけしか写真撮って残してない(^◇^;)
#
# 幹事さん、皆さん、
# 有難うございました！
#
# 鴨肉、燻製臭も素晴らしく絶品だった pic.twitter.com/GYYmVENrkp,
#
# TWEET--972298261343092741-...-T-0-0の出力完了
# nalunalu51,@midnitehour0404,59s59 seconds ago,got Bali Buda's Raw Honeylove this honey
# #bali
# #canggu
# #balibuda
# #美味しい
# #野菜の煮物にこのハチミツとココナッツシュガーを使う
# #1本はベストフレンドファミリーのお土産pic.twitter.com/xqZ1dsZysm,
#
# 大井川で逢いましょう,@oigawa_online,1m1 minute ago,大井川で逢いましょう
#
# SLフェスタin千頭
# 楽しいよー　美味しいものがたくさんあるから、
# 遊びに来てね～。,
#
# カフェログ,@cafeloggg,3m3 minutes ago,【カフェマメヒコ@渋谷】
# wifi・全席電源ありのノマドカフェ平日はあんまり混んでないし、静かで長居できる就活生の神様
# もちろんコーヒーが美味しいしご飯のメニューもちゃんとあります
# 今回は豆豆サラダとマメパンを食べましたどっちも美味しくてリピ決定
# #カフェログpic.twitter.com/FgYYC68NW5,
#
# 花,@hana0329,24m24 minutes ago,はぁ…はぁ……まだ子供なのでお肉が柔らかいですね…肉汁が滴るほどジューシーで…将来神絵師になりそうな……可能性の味がする……美味しい！！,
#
# 怒花亭　進虫＠小説家になろう&カクヨム,@meizin39,24m24 minutes ago,恐竜ハンターは美味しい仕事 - カクヨム https://kakuyomu.jp/works/1177354054885088631 …
# 表紙用にヒロインのセラミックこと瀬良美久さんを凄腕絵師キウイ将軍に描いてもらいました。pic.twitter.com/Z0PpTqj4k4,
#
# きみへー,@kimihei,49m49 minutes ago,ちょっと待って！焼き牡蠣に日本酒の振る舞いがあるんだけど！！歩道橋渡ったあと。小長井の牡蠣と日本酒・杵の川。超美味しいです！ご馳走さまです！！(*´ω｀*) pic.twitter.com/2A9GReFMEs,
#
# 神崎　司＠ニートライフ,@tsukasavivim01,50m50 minutes ago,好きなことをして、好きな場所に行き、美味しいものを食べて
# 日々充実しています♪
#
# 親孝行、彼女孝行もでき
# 毎日幸せになりました！
# LIEN＠でノウハウ配信中！
# http://changerion.info/w/29T2e8XC pic.twitter.com/wRXAeTdp4J,
#
# シャーレくんと名付け親,@ideschale,1h1 hour ago,諫早の駅からちょっと歩いてるだけで
# -がんばれレッズ  のプラカードを持った子供たちの一群
# -冷たいお茶どうぞー
# -美味しいプチトマトどうぞー
# と 息つく間もない
# これ、「歩かせる工夫」だよなー,
#
# オイカワマル,@oikawamaru,1h1 hour ago,水道水の水源となっているダムも、美味しい農作物を生産している干拓地も、私がいま乗っている新幹線も、多くの野生生物の生息地と命を奪ってできたものであることは、常々心の片隅に置いておくべきことなのです。,
#
# ニュージーランド政府観光局,@PureNZinJapan,2h2 hours ago,【プレゼントキャンペーン】旅サラダを見てNZに行きたくなりましたね！番組で紹介されたクイーンズタウンで、以下のどちらを体験してみたいですか？こちらのツイートをRTし質問に答えた方の中から抽選で@cookietimejp 様の美味しいクッキーをプレゼントいたします！ #旅サラダNZ　 #クッキータイム,
#
# 藤城リエ / りえ,@FujishiroRie,2h2 hours ago,みんな〜！！寒い中ありがとう〜！！暖かくしてね〜！あとフジヤマサイダーが美味しいよ〜！ pic.twitter.com/tbS2LnaIEA,
#
# JUN MASUDA,@intensive911,2h2 hours ago,#親子丼
# #美味しい #写真 #ブログ #japanesefood #instagood #instagram #instalike #instaphoto #instapic #instadaily #photography #photooftheday #photo #followmePlease check instagram"intensive911"pic.twitter.com/kZkpvyEJ3V,
#
# Fuwatto まるやまキッチン,@fuwattomaruyama,2h2 hours ago,3/10(土)札幌、久しぶりの晴れ
#
# もうここから春でしょ！！
#
# 今日は土曜日お出かけの日、天気もいいし～(*^▽^)/★*☆♪
#
# 本日も選んで楽しい見て嬉しい食べて美味しい～オムライスでお待ちしております。(*^ー^)ノ♪ pic.twitter.com/S5MegIPfGp,
#
# 「ここ一番美味しいとこ」 ✨,@twistedthursday,2h2 hours ago,ensemble cast of pure looking, nhk-approved actors ,
#
# 「ここ一番美味しいとこ」 ✨,@twistedthursday,2h2 hours ago,she appeared in the last two episodes, small role, but totally there xD gila deh, dan itu semua sebelum mereka je heroine. and two of the dudes too! sakaken in totonee and kengo kora in ohisama.,
#
# ÂK4Real @ Katsu-Edit Boat  ⛵️ | カレー美味しい,@OfficialAK4Real,3h3 hours ago,Hi I'm AK and I'm here to ruin the day.,
#
# 立ち上がれマスクマン,@7masukumann7,3h3 hours ago,おはようございます
# 福岡県マスクマン地域は朝から晴天
# 気持ちのよい土曜日ですね~
# 今日も笑顔で~
#
# やわもちシリーズ4つ目
# 「わらびもち」
# これも美味しいです！
# きなことわらびもちが絶妙〜
# 和アイス〜ハマりますね〜
#
# 今日も1日素敵な土曜日をお過ごしください
# よろしくです~ pic.twitter.com/BZeHr6uG6I,
#
# 不識庵謙信（影武者）,@fushikiankage,3h3 hours ago,３月９日『二郎 神田神保町』にて小ラーメンそのまま（初見だし神保町店は麺量が凄いと聞いていた＋ロットを崩さない為に）
# これが神田神保町店かー噂には聞いていたけど美味しい
# 肉も柔らかく最高でした
# そしてロット１抜けでした。
#
# ご馳走様でした pic.twitter.com/waJ3hP9k7H,
#
# しょ一けん,@sho_ken91,3h3 hours ago,松屋製麺所@つくば市
# らーめん＋山水で育ったご飯
#
# 今日の朝飯
# 鹿島へ行く前に久しぶりの訪問
# モチモチツルツルの麺に節の香りがいいスープ、美味い
# ご飯も美味しい
# ご馳走様でした pic.twitter.com/HXVp8awEo6,
#
# かくみや,@kakumiya66611,3h3 hours ago,昨夜の金町製麺
# 沢山美味しいお料理を頂きましたが
# 無精者のワタシはコレだけしか写真撮って残してない(^◇^;)
#
# 幹事さん、皆さん、
# 有難うございました！
#
# 鴨肉、燻製臭も素晴らしく絶品だった pic.twitter.com/GYYmVENrkp,
#
# TWEET--972298261343092741-...-T-0-0の出力完了
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-ee23442a04b4> in <module>()
#     139
#     140 # プログラム実行
# --> 141 getFirstTweet(crawle_word)
#
# <ipython-input-94-ee23442a04b4> in getFirstTweet(crawle_word)
#     136     #print(max_position)
#     137     # 次
# --> 138     getNextTweet(crawle_word, max_position)
#     139
#     140 # プログラム実行
#
# <ipython-input-94-ee23442a04b4> in getNextTweet(crawle_word, max_position)
#     106
#     107     # 再起的に呼び出す
# --> 108     getNextTweet(crawle_word, next_position)
#     109
#     110
#
# <ipython-input-94-ee23442a04b4> in getNextTweet(crawle_word, max_position)
#     106
#     107     # 再起的に呼び出す
# --> 108     getNextTweet(crawle_word, next_position)
#     109
#     110
#
# <ipython-input-94-ee23442a04b4> in getNextTweet(crawle_word, max_position)
#     106
#     107     # 再起的に呼び出す
# --> 108     getNextTweet(crawle_word, next_position)
#     109
#     110
#
# <ipython-input-94-ee23442a04b4> in getNextTweet(crawle_word, max_position)
#     103
#     104     # 一応スリープをかませる
# --> 105     sleep(1)
#     106
#     107     # 再起的に呼び出す
#
# KeyboardInterrupt:
